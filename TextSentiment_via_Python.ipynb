# %% [markdown]
# # Ask ChatGPT via Python (Translation Example)
#
# This notebook demonstrates how to call the OpenAI API from Python to generate text and translate it using ChatGPT.

# %%
from openai import OpenAI
import json
import requests
import os

# %%
key_location='C:\\Users\\user\\Desktop\\Coding\\OpenAPI_Key.txt'

with open(key_location, 'r') as file:
    key=file.readline().strip()

client=OpenAI(api_key=key)

# %%
def make_openai_request(prompt):
    response=client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7
    )
    return response.choices[0].message.content

# %%
input_text=[
    "The product quality is excellent and exceeded my expectations.",
    "Customer service was unhelpful and rude.",
    "Delivery was on time, but the packaging was damaged."
]

# %%
prompt=f"""
    Analyze the following customer feedbacks and determine the overall sentiment for each, e.g. happy, sad, angry, neutral. Provide the sentiment label only.
"""
for message in input_text:
    prompt+=f"\n- {message.strip()}"

# %%
classification=make_openai_request(prompt)
print("Classification:")
print(classification)
