# %% [markdown]
# # Ask ChatGPT via Python (Translation Example)
#
# This notebook demonstrates how to call the OpenAI API from Python to generate text and translate it using ChatGPT.

# %%
from openai import OpenAI
import json
import requests
import os

# %%
key_location='C:\\Users\\user\\Desktop\\Coding\\OpenAPI_Key.txt'

with open(key_location, 'r') as file:
    key=file.readline().strip()

client=OpenAI(api_key=key)

# %%
def make_openai_request(prompt):
    response=client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7
    )
    return response.choices[0].message.content

# %%
input_text="""
This website uses necessary and optional cookies. Necessary cookies ensure proper site functionality. Optional cookies, including cookies from third parties, require your consent and may enhance your experience, analyze usage, or deliver personalized content. Click “Allow All” to consent to optional cookies, “Reject All” to store only necessary cookies, or “Settings” for details on cookie use and control.
"""

# %%
prompt=f"""
    You will be provided with a block of text. Summarize the text in a concise manner, highlighting the key points and main ideas in one tweet. Ensure that the summary is clear and easy to understand.
    
    Input Text:
    ###
    {input_text}
    ###
"""

# %%
summary=make_openai_request(prompt)
print("Summary:")
print(summary)
